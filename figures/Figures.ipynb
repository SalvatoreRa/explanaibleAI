# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://raw.githubusercontent.com/SalvatoreRa/explanaibleAI/main/figures/survey_xai.txt', sep = '\t', index_col=0)

# %%
sns.lineplot(data= df)
plt.yscale('log')
plt.ylabel("Number of entries")
# Out:
# Text(0, 0.5, 'Number of entries')

# %%
df = pd.read_csv('https://raw.githubusercontent.com/SalvatoreRa/explanaibleAI/main/figures/survey_med.txt', sep = '\t', index_col=0)

# %%
sns.lineplot(data= df)
plt.yscale('log')
plt.ylabel("Number of entries")
# Out:
# Text(0, 0.5, 'Number of entries')
